# %%
import csv
file = open('aqx_p_432.csv',mode='r',encoding='utf-8',newline='')
csv_reader = csv.reader(file) #iterable的物件
for item in csv_reader:
    if(item[4]  != '良好'):
        print(item)
# Out:
# ['\ufeffsitename', 'county', 'aqi', 'pollutant', 'status', 'so2', 'co', 'o3', 'o3_8hr', 'pm10', 'pm2.5', 'no2', 'nox', 'no', 'wind_speed', 'wind_direc', 'publishtime', 'co_8hr', 'pm2.5_avg', 'pm10_avg', 'so2_avg', 'longitude', 'latitude', 'siteid']
# ['觀音', '桃園市', '58', '細懸浮微粒', '普通', '1', '0.24', '8', '19.6', '29', '17', '10.7', '11.9', '1.2', '2', '103', '2023/07/16 06:00:00', '0.2', '18.3', '31', '0', '121.08283092', '25.03556747', '19']
# ['豐原', '臺中市', '53', '細懸浮微粒', '普通', '1.5', '0.25', '10.9', '13', '24', '14', '5.7', '7.2', '1.5', '1.2', '101', '2023/07/16 06:00:00', '0.2', '16.5', '25', '2', '120.74252414', '24.25699731', '28']
# ['沙鹿', '臺中市', '51', '細懸浮微粒', '普通', '1', '0.18', '24', '21.7', '', '19', '5.6', '6.8', '1.2', '0.8', '75', '2023/07/16 06:00:00', '0.2', '15.6', '', '1', '120.568794', '24.225628', '29']
# ...

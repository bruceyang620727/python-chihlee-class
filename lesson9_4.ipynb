# %%
#抓出csv檔案內的資料

import csv
filename = 'aqx_p_432.csv'
with open(filename, encoding='utf-8', newline='') as file:
    data = csv.DictReader(file)
    #print(data) #看手冊知道DictReader傳出來是一個sequence資料，所以可以用for in
    #for item in data:
    #    print(item)
    data_list = list(data) #也可以用list()直接轉為list資料結構

data_list #為list資料結構，裡面儲存著dictionary
# Out:
# [{'sitename': '基隆',
#   'county': '基隆市',
#   'aqi': '19',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.6',
#   'co': '0.19',
#   'o3': '18.5',
#   'o3_8hr': '7.6',
#   'pm10': '',
#   'pm2.5': '5',
#   'no2': '5',
#   'nox': '7.4',
#   'no': '2.4',
#   'wind_speed': '1.7',
#   'wind_direc': '266',
#   'publishtime': '2023/07/23 08:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '5.8',
#   'pm10_avg': '',
#   'so2_avg': '0',
#   'longitude': '121.760056',
#   'latitude': '25.129167',
#   'siteid': '1'},
#  {'sitename': '汐止',
#   'county': '新北市',
#   'aqi': '20',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.5',
#   'co': '0.27',
#   'o3': '10.8',
#   'o3_8hr': '3.2',
#   'pm10': '21',
#   'pm2.5': '8',
#   'no2': '8.3',
#   'nox': '15.4',
#   'no': '7',
#   'wind_speed': '0.9',
#   'wind_direc': '172',
#   'publishtime': '2023/07/23 08:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '6.3',
#   'pm10_avg': '16',
#   'so2_avg': '1',
#   'longitude': '121.64081',
# ...

# %%
type(data_list)
# Out:
# list
